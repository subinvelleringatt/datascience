# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lego = pd.read_csv('C:\\Users\\sinsbv\\Desktop\\Project\\Kaggle\\Tutorial\\basic_descriptive_stats\\sets.csv')

# %%
lego
# Out:
#              set_num                                               name  year  \
# 0               00-1                                    Weetabix Castle  1970
# 1             0011-2                                  Town Mini-Figures  1978
# 2             0011-3                         Castle 2 for 1 Bonus Offer  1987
# 3             0012-1                                 Space Mini-Figures  1979
# 4             0013-1                                 Space Mini-Figures  1979
# 5             0014-1                                 Space Mini-Figures  1979
# 6             0015-1                                 Space Mini-Figures  1979
# 7             0016-1                                Castle Mini Figures  1978
# 8               00-2                       Weetabix Promotional House 1  1976
# 9               00-3                       Weetabix Promotional House 2  1976
# 10              00-4                      Weetabix Promotional Windmill  1976
# ...

# %%
lego.shape
# Out:
# (11673, 5)

# %%
lego.head()
# Out:
#   set_num                        name  year  theme_id  num_parts
# 0    00-1             Weetabix Castle  1970       414        471
# 1  0011-2           Town Mini-Figures  1978        84         12
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987       199          2
# 3  0012-1          Space Mini-Figures  1979       143         12
# 4  0013-1          Space Mini-Figures  1979       143         12

# %%
lego.num_parts.mean()
# Out:
# 162.26240041120533

# %%
lego.num_parts.median()
# Out:
# 45.0

# %%
lego.year.mode()
# Out:
# 0    2014
# dtype: int64

# %%
lego.num_parts.var()
# Out:
# 109026.82824430607

# %%
lego.num_parts.std()
# Out:
# 330.19210808907303

# %%
quartiles = [.25,.5,.75]
lego.num_parts.quantile(q=quartiles)
# Out:
# 0.25     10.0
# 0.50     45.0
# 0.75    172.0
# Name: num_parts, dtype: float64

# %%
lego.num_parts.describe()
# Out:
# count    11673.000000
# mean       162.262400
# std        330.192108
# min         -1.000000
# 25%         10.000000
# 50%         45.000000
# 75%        172.000000
# max       5922.000000
# Name: num_parts, dtype: float64
